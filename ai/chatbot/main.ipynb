# %%
import torch
from kogpt2_transformers import get_kogpt2_model, get_kogpt2_tokenizer

# %%
torch.manual_seed(42)

model = get_kogpt2_model()
tokenizer = get_kogpt2_tokenizer()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-2-ace41bd1f589> in <module>
#       1 torch.manual_seed(42)
#       2
# ----> 3 model = get_kogpt2_model()
#       4 tokenizer = get_kogpt2_tokenizer()
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\kogpt2_transformers\load_model.py in get_kogpt2_model(model_path)
#       5     if not model_path:
#       6         model_path = 'taeminlee/kogpt2'
# ----> 7     model = GPT2LMHeadModel.from_pretrained(model_path)
#       8     return model
#       9
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\transformers\modeling_utils.py in from_pretrained(cls, pretrained_model_name_or_path, *model_args, **kwargs)
#     670
#     671         # Instantiate model.
# --> 672         model = cls(config, *model_args, **model_kwargs)
#     673
#     674         if state_dict is None and not from_tf:
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\transformers\modeling_gpt2.py in __init__(self, config)
#     529     def __init__(self, config):
#     530         super().__init__(config)
# --> 531         self.transformer = GPT2Model(config)
#     532         self.lm_head = nn.Linear(config.n_embd, config.vocab_size, bias=False)
#     533
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\transformers\modeling_gpt2.py in __init__(self, config)
#     354         self.wpe = nn.Embedding(config.n_positions, config.n_embd)
#     355         self.drop = nn.Dropout(config.embd_pdrop)
# --> 356         self.h = nn.ModuleList([Block(config.n_ctx, config, scale=True) for _ in range(config.n_layer)])
#     357         self.ln_f = nn.LayerNorm(config.n_embd, eps=config.layer_norm_epsilon)
#     358
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\transformers\modeling_gpt2.py in <listcomp>(.0)
#     354         self.wpe = nn.Embedding(config.n_positions, config.n_embd)
#     355         self.drop = nn.Dropout(config.embd_pdrop)
# --> 356         self.h = nn.ModuleList([Block(config.n_ctx, config, scale=True) for _ in range(config.n_layer)])
#     357         self.ln_f = nn.LayerNorm(config.n_embd, eps=config.layer_norm_epsilon)
#     358
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\transformers\modeling_gpt2.py in __init__(self, n_ctx, config, scale)
#     230         nx = config.n_embd
#     231         self.ln_1 = nn.LayerNorm(nx, eps=config.layer_norm_epsilon)
# --> 232         self.attn = Attention(nx, n_ctx, config, scale)
#     233         self.ln_2 = nn.LayerNorm(nx, eps=config.layer_norm_epsilon)
#     234         self.mlp = MLP(4 * nx, config)
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\transformers\modeling_gpt2.py in __init__(self, nx, n_ctx, config, scale)
#     121         self.scale = scale
#     122
# --> 123         self.c_attn = Conv1D(n_state * 3, nx)
#     124         self.c_proj = Conv1D(n_state, nx)
#     125         self.attn_dropout = nn.Dropout(config.attn_pdrop)
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\transformers\modeling_utils.py in __init__(self, nf, nx)
#     812         self.nf = nf
#     813         w = torch.empty(nx, nf)
# --> 814         nn.init.normal_(w, std=0.02)
#     815         self.weight = nn.Parameter(w)
#     816         self.bias = nn.Parameter(torch.zeros(nf))
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\torch\nn\init.py in normal_(tensor, mean, std)
#     140         >>> nn.init.normal_(w)
#     141     """
# --> 142     return _no_grad_normal_(tensor, mean, std)
#     143
#     144 def trunc_normal_(tensor, mean=0., std=1., a=-2., b=2.):
#
# ~\AppData\Local\Programs\Python\Python36\lib\site-packages\torch\nn\init.py in _no_grad_normal_(tensor, mean, std)
#      19 def _no_grad_normal_(tensor, mean, std):
#      20     with torch.no_grad():
# ---> 21         return tensor.normal_(mean, std)
#      22
#      23
#
# KeyboardInterrupt:

# %%
input_ids = tokenizer.encode("안녕", add_special_tokens=False, return_tensors="pt")
output_sequences = model.generate(input_ids=input_ids, do_sample=True, max_length=100, num_return_sequences=3)
for generated_sequence in output_sequences:
    generated_sequence = generated_sequence.tolist()
    print("GENERATED SEQUENCE : {0}".format(tokenizer.decode(generated_sequence, clean_up_tokenization_spaces=True)))
